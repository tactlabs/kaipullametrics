# %%
import prettymetrics

from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0     2.30    0
# 1   37    1   2     130   250    0        1       187     0     3.50    0
# 2   41    0   1     130   204    0        0       172     0     1.40    2
# 3   56    1   1     120   236    0        1       178     0     0.80    2
# 4   57    0   0     120   354    0        1       163     1     0.60    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
X = data.drop(['output'], axis = 1)
y = data['output']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 43/43 [00:02<00:00, 14.61it/s]

# %%
models
# Out:
#                                 Accuracy  Balanced Accuracy  ROC AUC  \
# Model
# KNeighborsClassifier                0.84               0.84     0.84
# Perceptron                          0.82               0.82     0.82
# BernoulliNB                         0.81               0.81     0.81
# GaussianNB                          0.81               0.81     0.81
# RandomForestClassifier              0.81               0.81     0.81
# NearestCentroid                     0.81               0.81     0.81
# LogisticRegression                  0.81               0.81     0.81
# SGDClassifier                       0.81               0.81     0.81
# LinearSVC                           0.80               0.80     0.80
# CalibratedClassifierCV              0.80               0.80     0.80
# QuadraticDiscriminantAnalysis       0.80               0.80     0.80
# AdaBoostClassifier                  0.80               0.80     0.80
# GaussianProcessClassifier           0.79               0.79     0.79
# HistGradientBoostingClassifier      0.79               0.79     0.79
# LinearDiscriminantAnalysis          0.79               0.79     0.79
# RidgeClassifierCV                   0.79               0.79     0.79
# RidgeClassifier                     0.79               0.79     0.79
# GradientBoostingClassifier          0.79               0.79     0.79
# DecisionTreeClassifier              0.79               0.79     0.79
# PassiveAggressiveClassifier         0.79               0.79     0.79
# LogisticRegressionCV                0.78               0.78     0.78
# MLPClassifier                       0.77               0.77     0.77
# ExtraTreesClassifier                0.77               0.77     0.77
# NuSVC                               0.77               0.77     0.77
# SVC                                 0.77               0.77     0.77
# XGBClassifier                       0.77               0.77     0.77
# ExtraTreeClassifier                 0.76               0.76     0.76
# LabelPropagation                    0.76               0.76     0.76
# LabelSpreading                      0.76               0.76     0.76
# BaggingClassifier                   0.75               0.75     0.75
# LGBMClassifier                      0.74               0.74     0.74
# DummyClassifier                     0.51               0.50     0.50
#
#                                 F1 Score  Time Taken
# Model
# KNeighborsClassifier                0.84        0.02
# Perceptron                          0.82        0.03
# BernoulliNB                         0.81        0.01
# GaussianNB                          0.81        0.02
# RandomForestClassifier              0.81        0.17
# NearestCentroid                     0.81        0.05
# LogisticRegression                  0.81        0.03
# SGDClassifier                       0.81        0.01
# LinearSVC                           0.80        0.03
# CalibratedClassifierCV              0.80        0.06
# QuadraticDiscriminantAnalysis       0.80        0.02
# AdaBoostClassifier                  0.80        0.14
# GaussianProcessClassifier           0.79        0.07
# HistGradientBoostingClassifier      0.79        0.31
# LinearDiscriminantAnalysis          0.79        0.02
# RidgeClassifierCV                   0.79        0.02
# RidgeClassifier                     0.79        0.02
# GradientBoostingClassifier          0.79        0.25
# DecisionTreeClassifier              0.79        0.02
# PassiveAggressiveClassifier         0.79        0.03
# LogisticRegressionCV                0.78        0.18
# MLPClassifier                       0.77        0.91
# ExtraTreesClassifier                0.77        0.14
# NuSVC                               0.77        0.05
# SVC                                 0.77        0.02
# XGBClassifier                       0.77        0.04
# ExtraTreeClassifier                 0.76        0.01
# LabelPropagation                    0.76        0.02
# LabelSpreading                      0.76        0.03
# BaggingClassifier                   0.75        0.04
# LGBMClassifier                      0.73        0.07
# DummyClassifier                     0.34        0.02
