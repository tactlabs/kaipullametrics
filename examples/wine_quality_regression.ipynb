# %%
import prettymetrics

from prettymetrics.supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                 34.00     1.00 3.51       0.56
# 1                25.00                 67.00     1.00 3.20       0.68
# 2                15.00                 54.00     1.00 3.26       0.65
# 3                17.00                 60.00     1.00 3.16       0.58
# 4                11.00                 34.00     1.00 3.51       0.56
#
#    alcohol  quality
# 0     9.40        5
# 1     9.80        5
# 2     9.80        5
# 3     9.80        6
# 4     9.40        5

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X = data.drop(["quality"], axis = 1)
y = data["quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 56/56 [00:07<00:00,  7.99it/s]

# %%
models
# Out:
#                                                       Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                                 0.50
# RandomForestRegressor                                               0.46
# BaggingRegressor                                                    0.44
# LGBMRegressor                                                       0.42
# HistGradientBoostingRegressor                                       0.42
# SVR                                                                 0.41
# NuSVR                                                               0.41
# XGBRegressor                                                        0.40
# GradientBoostingRegressor                                           0.38
# HuberRegressor                                                      0.32
# LinearRegression                                                    0.32
# TransformedTargetRegressor                                          0.32
# Lars                                                                0.32
# Ridge                                                               0.32
# RidgeCV                                                             0.32
# LinearSVR                                                           0.32
# BayesianRidge                                                       0.32
# SGDRegressor                                                        0.32
# AdaBoostRegressor                                                   0.31
# ARDRegression                                                       0.31
# LassoCV                                                             0.31
# LassoLarsCV                                                         0.31
# LarsCV                                                              0.31
# ElasticNetCV                                                        0.31
# TheilSenRegressor                                                   0.31
# LassoLarsIC                                                         0.31
# PoissonRegressor                                                    0.31
# OrthogonalMatchingPursuitCV                                         0.30
# PLSRegression                                                       0.28
# MLPRegressor                                                        0.28
# KNeighborsRegressor                                                 0.25
# GammaRegressor                                                      0.25
# TweedieRegressor                                                    0.25
# OrthogonalMatchingPursuit                                           0.19
# RANSACRegressor                                                     0.17
# CCA                                                                 0.05
# DecisionTreeRegressor                                              -0.00
# DummyRegressor                                                     -0.04
# ElasticNet                                                         -0.04
# Lasso                                                              -0.04
# LassoLars                                                          -0.04
# ExtraTreeRegressor                                                 -0.17
# PLSCanonical                                                       -0.26
# PassiveAggressiveRegressor                                         -1.16
# GaussianProcessRegressor                                           -2.52
# KernelRidge                                                       -49.25
# RadiusNeighborsRegressor      -60951473243680514929743645938196414464.00
#
#                                                                R-Squared  \
# Model
# ExtraTreesRegressor                                                 0.51
# RandomForestRegressor                                               0.48
# BaggingRegressor                                                    0.46
# LGBMRegressor                                                       0.44
# HistGradientBoostingRegressor                                       0.44
# SVR                                                                 0.44
# NuSVR                                                               0.43
# XGBRegressor                                                        0.42
# GradientBoostingRegressor                                           0.40
# HuberRegressor                                                      0.35
# LinearRegression                                                    0.34
# TransformedTargetRegressor                                          0.34
# Lars                                                                0.34
# Ridge                                                               0.34
# RidgeCV                                                             0.34
# LinearSVR                                                           0.34
# BayesianRidge                                                       0.34
# SGDRegressor                                                        0.34
# AdaBoostRegressor                                                   0.34
# ARDRegression                                                       0.34
# LassoCV                                                             0.33
# LassoLarsCV                                                         0.33
# LarsCV                                                              0.33
# ElasticNetCV                                                        0.33
# TheilSenRegressor                                                   0.33
# LassoLarsIC                                                         0.33
# PoissonRegressor                                                    0.33
# OrthogonalMatchingPursuitCV                                         0.32
# PLSRegression                                                       0.31
# MLPRegressor                                                        0.31
# KNeighborsRegressor                                                 0.28
# GammaRegressor                                                      0.27
# TweedieRegressor                                                    0.27
# OrthogonalMatchingPursuit                                           0.22
# RANSACRegressor                                                     0.19
# CCA                                                                 0.08
# DecisionTreeRegressor                                               0.03
# DummyRegressor                                                     -0.00
# ElasticNet                                                         -0.00
# Lasso                                                              -0.00
# LassoLars                                                          -0.00
# ExtraTreeRegressor                                                 -0.13
# PLSCanonical                                                       -0.21
# PassiveAggressiveRegressor                                         -1.08
# GaussianProcessRegressor                                           -2.40
# KernelRidge                                                       -47.51
# RadiusNeighborsRegressor      -58849698304243248954945855370496573440.00
#
#                                                 RMSE  Time Taken
# Model
# ExtraTreesRegressor                             0.57        0.38
# RandomForestRegressor                           0.59        0.63
# BaggingRegressor                                0.60        0.07
# LGBMRegressor                                   0.61        0.09
# HistGradientBoostingRegressor                   0.61        0.43
# SVR                                             0.61        0.15
# NuSVR                                           0.62        0.15
# XGBRegressor                                    0.62        0.30
# GradientBoostingRegressor                       0.63        0.35
# HuberRegressor                                  0.66        0.05
# LinearRegression                                0.66        0.01
# TransformedTargetRegressor                      0.66        0.01
# Lars                                            0.66        0.02
# Ridge                                           0.66        0.01
# RidgeCV                                         0.66        0.02
# LinearSVR                                       0.66        0.04
# BayesianRidge                                   0.66        0.01
# SGDRegressor                                    0.66        0.01
# AdaBoostRegressor                               0.66        0.23
# ARDRegression                                   0.66        0.06
# LassoCV                                         0.67        0.10
# LassoLarsCV                                     0.67        0.04
# LarsCV                                          0.67        0.03
# ElasticNetCV                                    0.67        0.17
# TheilSenRegressor                               0.67        0.84
# LassoLarsIC                                     0.67        0.02
# PoissonRegressor                                0.67        0.02
# OrthogonalMatchingPursuitCV                     0.67        0.02
# PLSRegression                                   0.68        0.01
# MLPRegressor                                    0.68        1.83
# KNeighborsRegressor                             0.69        0.02
# GammaRegressor                                  0.69        0.01
# TweedieRegressor                                0.69        0.01
# OrthogonalMatchingPursuit                       0.72        0.03
# RANSACRegressor                                 0.73        0.11
# CCA                                             0.78        0.01
# DecisionTreeRegressor                           0.80        0.02
# DummyRegressor                                  0.82        0.01
# ElasticNet                                      0.82        0.02
# Lasso                                           0.82        0.02
# LassoLars                                       0.82        0.02
# ExtraTreeRegressor                              0.87        0.02
# PLSCanonical                                    0.90        0.01
# PassiveAggressiveRegressor                      1.18        0.01
# GaussianProcessRegressor                        1.50        0.33
# KernelRidge                                     5.68        0.11
# RadiusNeighborsRegressor      6251344101557402624.00        0.04
