# %% [markdown]
# ### Classification of diabetes.csv

# %%
import pandas as pd

# %%
from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('datasets/diabetes.csv')

# %%
df
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# 766                                                126
# 767                                                 93
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                  72                                35
# 1                                  66                                29
# 2                                  64                                 0
# 3                                  66                                23
# 4                                  40                                35
# ..                                ...                               ...
# 763                                76                                48
# 764                                70                                27
# 765                                72                                23
# 766                                60                                 0
# 767                                70                                31
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                94
# 4                               168
# ..                              ...
# 763                             180
# 764                               0
# 765                             112
# 766                               0
# 767                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                              33.6
# 1                                              26.6
# 2                                              23.3
# 3                                              28.1
# 4                                              43.1
# ..                                              ...
# 763                                            32.9
# 764                                            36.8
# 765                                            26.2
# 766                                            30.1
# 767                                            30.4
#
#      Diabetes pedigree function  Age (years)  Class variable
# 0                         0.627           50               1
# 1                         0.351           31               0
# 2                         0.672           32               1
# 3                         0.167           21               0
# 4                         2.288           33               1
# ..                          ...          ...             ...
# 763                       0.171           63               0
# 764                       0.340           27               0
# 765                       0.245           30               0
# 766                       0.349           47               1
# 767                       0.315           23               0
#
# [768 rows x 9 columns]

# %%
X=df[df.columns[:-1]]
y=df['Class variable']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 43/43 [00:02<00:00, 14.97it/s]

# %%
print(models)
# Out:
#                                 Accuracy  Balanced Accuracy  ROC AUC  \
# Model
# GradientBoostingClassifier          0.78               0.76     0.76
# Perceptron                          0.75               0.75     0.75
# GaussianNB                          0.77               0.74     0.74
# QuadraticDiscriminantAnalysis       0.77               0.73     0.73
# NearestCentroid                     0.74               0.73     0.73
# PassiveAggressiveClassifier         0.74               0.73     0.73
# RandomForestClassifier              0.77               0.73     0.73
# MLPClassifier                       0.76               0.73     0.73
# HistGradientBoostingClassifier      0.75               0.73     0.73
# LogisticRegression                  0.77               0.73     0.73
# LogisticRegressionCV                0.77               0.73     0.73
# AdaBoostClassifier                  0.74               0.72     0.72
# LinearSVC                           0.77               0.72     0.72
# CalibratedClassifierCV              0.76               0.72     0.72
# LinearDiscriminantAnalysis          0.76               0.72     0.72
# GaussianProcessClassifier           0.76               0.72     0.72
# ExtraTreesClassifier                0.76               0.72     0.72
# SGDClassifier                       0.74               0.72     0.72
# RidgeClassifier                     0.76               0.72     0.72
# RidgeClassifierCV                   0.76               0.72     0.72
# LGBMClassifier                      0.74               0.71     0.71
# XGBClassifier                       0.74               0.71     0.71
# NuSVC                               0.75               0.71     0.71
# BaggingClassifier                   0.74               0.71     0.71
# LabelSpreading                      0.72               0.69     0.69
# SVC                                 0.74               0.69     0.69
# LabelPropagation                    0.72               0.69     0.69
# BernoulliNB                         0.71               0.68     0.68
# KNeighborsClassifier                0.71               0.67     0.67
# DecisionTreeClassifier              0.69               0.67     0.67
# ExtraTreeClassifier                 0.65               0.62     0.62
# DummyClassifier                     0.62               0.50     0.50
#
#                                 F1 Score  Time Taken
# Model
# GradientBoostingClassifier          0.78        0.14
# Perceptron                          0.75        0.01
# GaussianNB                          0.76        0.02
# QuadraticDiscriminantAnalysis       0.76        0.01
# NearestCentroid                     0.74        0.02
# PassiveAggressiveClassifier         0.74        0.03
# RandomForestClassifier              0.76        0.14
# MLPClassifier                       0.76        0.92
# HistGradientBoostingClassifier      0.75        0.40
# LogisticRegression                  0.76        0.02
# LogisticRegressionCV                0.76        0.17
# AdaBoostClassifier                  0.74        0.13
# LinearSVC                           0.76        0.02
# CalibratedClassifierCV              0.75        0.09
# LinearDiscriminantAnalysis          0.75        0.01
# GaussianProcessClassifier           0.75        0.12
# ExtraTreesClassifier                0.75        0.11
# SGDClassifier                       0.74        0.01
# RidgeClassifier                     0.75        0.02
# RidgeClassifierCV                   0.75        0.01
# LGBMClassifier                      0.74        0.11
# XGBClassifier                       0.74        0.07
# NuSVC                               0.74        0.04
# BaggingClassifier                   0.74        0.04
# LabelSpreading                      0.72        0.02
# SVC                                 0.72        0.02
# LabelPropagation                    0.72        0.02
# BernoulliNB                         0.71        0.01
# KNeighborsClassifier                0.70        0.03
# DecisionTreeClassifier              0.69        0.02
# ExtraTreeClassifier                 0.65        0.01
# DummyClassifier                     0.48        0.01
