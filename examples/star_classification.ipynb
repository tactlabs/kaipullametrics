# %%
import prettymetrics

from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/Star_data.csv")

# %%
data.head()
# Out:
#    Vmag   Plx  e_Plx   B-V SpType  Amag  TargetClass
# 0  5.99 13.73   0.58  1.32  K5III 16.68            0
# 1  8.70  2.31   1.29 -0.04   B1II 15.52            0
# 2  5.77  5.50   1.03  0.85  G5III 14.47            0
# 3  6.72  5.26   0.74 -0.01    B7V 15.32            1
# 4  8.76 13.44   1.16  0.58    G0V 19.40            1

# %%
from sklearn.preprocessing import LabelEncoder

SpType_le = LabelEncoder()

data['SpType'] = SpType_le.fit_transform(data.SpType)

# %%
data.head()
# Out:
#    Vmag   Plx  e_Plx   B-V  SpType  Amag  TargetClass
# 0  5.99 13.73   0.58  1.32     522 16.68            0
# 1  8.70  2.31   1.29 -0.04      99 15.52            0
# 2  5.77  5.50   1.03  0.85     337 14.47            0
# 3  6.72  5.26   0.74 -0.01     150 15.32            1
# 4  8.76 13.44   1.16  0.58     293 19.40            1

# %%
X = data.drop(['TargetClass'], axis = 1)
y = data['TargetClass']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 43/43 [00:27<00:00,  1.55it/s]

# %%
models
# Out:
#                                 Accuracy  Balanced Accuracy  ROC AUC  \
# Model
# HistGradientBoostingClassifier      0.94               0.94     0.94
# XGBClassifier                       0.94               0.94     0.94
# LGBMClassifier                      0.93               0.93     0.93
# RandomForestClassifier              0.93               0.93     0.93
# GradientBoostingClassifier          0.92               0.92     0.92
# ExtraTreesClassifier                0.92               0.92     0.92
# BaggingClassifier                   0.92               0.92     0.92
# GaussianProcessClassifier           0.91               0.91     0.91
# SVC                                 0.91               0.91     0.91
# LinearSVC                           0.91               0.91     0.91
# LogisticRegression                  0.91               0.91     0.91
# LogisticRegressionCV                0.91               0.91     0.91
# MLPClassifier                       0.91               0.91     0.91
# CalibratedClassifierCV              0.91               0.91     0.91
# SGDClassifier                       0.91               0.91     0.91
# LinearDiscriminantAnalysis          0.91               0.91     0.91
# RidgeClassifier                     0.91               0.91     0.91
# RidgeClassifierCV                   0.90               0.90     0.90
# GaussianNB                          0.90               0.90     0.90
# AdaBoostClassifier                  0.90               0.90     0.90
# KNeighborsClassifier                0.90               0.90     0.90
# LabelPropagation                    0.90               0.90     0.90
# LabelSpreading                      0.90               0.90     0.90
# DecisionTreeClassifier              0.90               0.90     0.90
# NearestCentroid                     0.90               0.90     0.90
# NuSVC                               0.90               0.90     0.90
# PassiveAggressiveClassifier         0.90               0.90     0.90
# ExtraTreeClassifier                 0.88               0.88     0.88
# BernoulliNB                         0.88               0.88     0.88
# QuadraticDiscriminantAnalysis       0.87               0.87     0.87
# Perceptron                          0.84               0.84     0.84
# DummyClassifier                     0.48               0.50     0.50
#
#                                 F1 Score  Time Taken
# Model
# HistGradientBoostingClassifier      0.94        1.96
# XGBClassifier                       0.94        0.83
# LGBMClassifier                      0.93        0.67
# RandomForestClassifier              0.93        0.60
# GradientBoostingClassifier          0.92        0.66
# ExtraTreesClassifier                0.92        0.35
# BaggingClassifier                   0.92        0.15
# GaussianProcessClassifier           0.91       11.68
# SVC                                 0.91        0.24
# LinearSVC                           0.91        0.23
# LogisticRegression                  0.91        0.04
# LogisticRegressionCV                0.91        0.79
# MLPClassifier                       0.91        6.76
# CalibratedClassifierCV              0.91        0.50
# SGDClassifier                       0.91        0.05
# LinearDiscriminantAnalysis          0.91        0.08
# RidgeClassifier                     0.91        0.02
# RidgeClassifierCV                   0.90        0.07
# GaussianNB                          0.90        0.02
# AdaBoostClassifier                  0.90        0.27
# KNeighborsClassifier                0.90        0.07
# LabelPropagation                    0.90        0.34
# LabelSpreading                      0.90        0.63
# DecisionTreeClassifier              0.90        0.05
# NearestCentroid                     0.90        0.03
# NuSVC                               0.90        0.41
# PassiveAggressiveClassifier         0.90        0.03
# ExtraTreeClassifier                 0.88        0.03
# BernoulliNB                         0.88        0.03
# QuadraticDiscriminantAnalysis       0.87        0.02
# Perceptron                          0.84        0.02
# DummyClassifier                     0.31        0.02
