# %%
import prettymetrics

from prettymetrics.supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/possum.csv")

# %%
data.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m 8.00    94.10   60.40     89.00  36.00     74.50
# 1     2     1  Vic   f 6.00    92.50   57.60     91.50  36.50     72.50
# 2     3     1  Vic   f 6.00    94.00   60.00     95.50  39.00     75.40
# 3     4     1  Vic   f 6.00    93.20   57.10     92.00  38.00     76.10
# 4     5     1  Vic   f 2.00    91.50   56.30     85.50  36.00     71.00
#
#    earconch   eye  chest  belly
# 0     54.50 15.20  28.00  36.00
# 1     51.20 16.00  28.50  33.00
# 2     51.90 15.50  30.00  34.00
# 3     52.20 15.20  28.00  34.00
# 4     53.20 15.10  28.50  33.00

# %%
data.isnull().sum()
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         2
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    1
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
data = data.dropna()

# %%
from  sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data["Pop"] = le.fit_transform(data.Pop)
data["sex"] = le.fit_transform(data.sex)

# %%
data.head()
# Out:
#    case  site  Pop  sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1    0    1 8.00    94.10   60.40     89.00  36.00     74.50
# 1     2     1    0    0 6.00    92.50   57.60     91.50  36.50     72.50
# 2     3     1    0    0 6.00    94.00   60.00     95.50  39.00     75.40
# 3     4     1    0    0 6.00    93.20   57.10     92.00  38.00     76.10
# 4     5     1    0    0 2.00    91.50   56.30     85.50  36.00     71.00
#
#    earconch   eye  chest  belly
# 0     54.50 15.20  28.00  36.00
# 1     51.20 16.00  28.50  33.00
# 2     51.90 15.50  30.00  34.00
# 3     52.20 15.20  28.00  34.00
# 4     53.20 15.10  28.50  33.00

# %%
X = data.drop(["age"], axis =1)
y = data["age"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 56/56 [00:02<00:00, 26.17it/s]

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# BaggingRegressor                            -1.11       0.26  1.98        0.03
# PLSRegression                               -1.27       0.20  2.05        0.01
# GammaRegressor                              -1.32       0.19  2.07        0.01
# NuSVR                                       -1.38       0.17  2.10        0.01
# AdaBoostRegressor                           -1.39       0.16  2.10        0.10
# TweedieRegressor                            -1.41       0.16  2.11        0.01
# DecisionTreeRegressor                       -1.42       0.15  2.12        0.01
# RandomForestRegressor                       -1.42       0.15  2.12        0.11
# ExtraTreesRegressor                         -1.42       0.15  2.12        0.09
# BayesianRidge                               -1.43       0.15  2.12        0.02
# LGBMRegressor                               -1.44       0.15  2.13        0.03
# HistGradientBoostingRegressor               -1.46       0.14  2.13        0.24
# SVR                                         -1.53       0.11  2.17        0.01
# OrthogonalMatchingPursuitCV                 -1.56       0.10  2.18        0.01
# OrthogonalMatchingPursuit                   -1.56       0.10  2.18        0.01
# GradientBoostingRegressor                   -1.58       0.10  2.19        0.06
# PoissonRegressor                            -1.59       0.09  2.19        0.01
# LassoLarsIC                                 -1.61       0.09  2.20        0.01
# ElasticNetCV                                -1.62       0.08  2.20        0.06
# LassoCV                                     -1.68       0.06  2.23        0.11
# LassoLarsCV                                 -1.71       0.05  2.24        0.03
# LarsCV                                      -1.71       0.05  2.24        0.03
# ARDRegression                               -1.72       0.05  2.24        0.04
# RidgeCV                                     -1.76       0.03  2.26        0.01
# ElasticNet                                  -1.86       0.00  2.30        0.01
# XGBRegressor                                -1.90      -0.01  2.32        0.03
# CCA                                         -1.91      -0.02  2.32        0.01
# LassoLars                                   -1.91      -0.02  2.32        0.01
# DummyRegressor                              -1.91      -0.02  2.32        0.01
# Lasso                                       -1.91      -0.02  2.32        0.01
# KNeighborsRegressor                         -1.92      -0.02  2.32        0.01
# MLPRegressor                                -1.97      -0.04  2.34        0.08
# SGDRegressor                                -2.07      -0.08  2.39        0.01
# TheilSenRegressor                           -2.07      -0.08  2.39        0.67
# PassiveAggressiveRegressor                  -2.11      -0.09  2.40        0.01
# LinearSVR                                   -2.19      -0.12  2.43        0.01
# Ridge                                       -2.28      -0.15  2.47        0.01
# TransformedTargetRegressor                  -2.45      -0.21  2.53        0.01
# LinearRegression                            -2.45      -0.21  2.53        0.01
# Lars                                        -2.45      -0.21  2.53        0.01
# HuberRegressor                              -2.46      -0.21  2.53        0.02
# ExtraTreeRegressor                          -2.86      -0.35  2.67        0.01
# GaussianProcessRegressor                    -2.98      -0.39  2.71        0.03
# PLSCanonical                                -3.69      -0.64  2.95        0.01
# RANSACRegressor                             -6.05      -1.47  3.61        0.04
# KernelRidge                                 -8.55      -2.34  4.21        0.01
