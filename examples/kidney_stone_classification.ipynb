# %%
import prettymetrics

from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/kidney_stone_data.csv")

# %%
data.head()
# Out:
#   treatment stone_size  success
# 0         B      large        1
# 1         A      large        1
# 2         A      large        0
# 3         A      large        1
# 4         A      large        1

# %%
data.stone_size.unique()
# Out:
# array(['large', 'small'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['stone_size'] = le.fit_transform(data.stone_size)
data['treatment'] = le.fit_transform(data.treatment)

# %%
data.head()
# Out:
#    treatment  stone_size  success
# 0          1           0        1
# 1          0           0        1
# 2          0           0        0
# 3          0           0        1
# 4          0           0        1

# %%
X = data.drop(['success'], axis = 1)
y = data['success']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 43/43 [00:02<00:00, 17.87it/s]

# %%
models
# Out:
#                                 Accuracy  Balanced Accuracy  ROC AUC  \
# Model
# NearestCentroid                     0.54               0.60     0.60
# KNeighborsClassifier                0.75               0.54     0.54
# AdaBoostClassifier                  0.80               0.50     0.50
# BaggingClassifier                   0.80               0.50     0.50
# XGBClassifier                       0.80               0.50     0.50
# SVC                                 0.80               0.50     0.50
# SGDClassifier                       0.80               0.50     0.50
# RidgeClassifierCV                   0.80               0.50     0.50
# RidgeClassifier                     0.80               0.50     0.50
# RandomForestClassifier              0.80               0.50     0.50
# RadiusNeighborsClassifier           0.80               0.50     0.50
# QuadraticDiscriminantAnalysis       0.80               0.50     0.50
# PassiveAggressiveClassifier         0.80               0.50     0.50
# MLPClassifier                       0.80               0.50     0.50
# LogisticRegressionCV                0.80               0.50     0.50
# LogisticRegression                  0.80               0.50     0.50
# LinearSVC                           0.80               0.50     0.50
# LinearDiscriminantAnalysis          0.80               0.50     0.50
# LabelSpreading                      0.80               0.50     0.50
# LabelPropagation                    0.80               0.50     0.50
# HistGradientBoostingClassifier      0.80               0.50     0.50
# GradientBoostingClassifier          0.80               0.50     0.50
# GaussianProcessClassifier           0.80               0.50     0.50
# GaussianNB                          0.80               0.50     0.50
# ExtraTreesClassifier                0.80               0.50     0.50
# ExtraTreeClassifier                 0.80               0.50     0.50
# DummyClassifier                     0.80               0.50     0.50
# DecisionTreeClassifier              0.80               0.50     0.50
# CalibratedClassifierCV              0.80               0.50     0.50
# BernoulliNB                         0.80               0.50     0.50
# LGBMClassifier                      0.80               0.50     0.50
# Perceptron                          0.56               0.44     0.44
#
#                                 F1 Score  Time Taken
# Model
# NearestCentroid                     0.59        0.03
# KNeighborsClassifier                0.73        0.02
# AdaBoostClassifier                  0.71        0.10
# BaggingClassifier                   0.71        0.03
# XGBClassifier                       0.71        0.02
# SVC                                 0.71        0.02
# SGDClassifier                       0.71        0.01
# RidgeClassifierCV                   0.71        0.01
# RidgeClassifier                     0.71        0.02
# RandomForestClassifier              0.71        0.18
# RadiusNeighborsClassifier           0.71        0.03
# QuadraticDiscriminantAnalysis       0.71        0.02
# PassiveAggressiveClassifier         0.71        0.03
# MLPClassifier                       0.71        0.49
# LogisticRegressionCV                0.71        0.14
# LogisticRegression                  0.71        0.02
# LinearSVC                           0.71        0.02
# LinearDiscriminantAnalysis          0.71        0.02
# LabelSpreading                      0.71        0.05
# LabelPropagation                    0.71        0.04
# HistGradientBoostingClassifier      0.71        0.19
# GradientBoostingClassifier          0.71        0.23
# GaussianProcessClassifier           0.71        0.34
# GaussianNB                          0.71        0.01
# ExtraTreesClassifier                0.71        0.11
# ExtraTreeClassifier                 0.71        0.01
# DummyClassifier                     0.71        0.01
# DecisionTreeClassifier              0.71        0.01
# CalibratedClassifierCV              0.71        0.04
# BernoulliNB                         0.71        0.01
# LGBMClassifier                      0.71        0.03
# Perceptron                          0.59        0.03
