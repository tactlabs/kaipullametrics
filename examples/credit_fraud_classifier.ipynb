# %%
import pandas as pd
import numpy as np
import prettymetrics
from prettymetrics.supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/home/dhanya/Desktop/tact/Datasets/credit_fraud/creditcard.csv')
df.head()
# Out:
#    Time    V1    V2   V3    V4    V5    V6    V7    V8    V9  ...   V21   V22  \
# 0  0.00 -1.36 -0.07 2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.02  0.28
# 1  0.00  1.19  0.27 0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23 -0.64
# 2  1.00 -1.36 -1.34 1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.25  0.77
# 3  1.00 -0.97 -0.19 1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.11  0.01
# 4  2.00 -1.16  0.88 1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.01  0.80
#
#     V23   V24   V25   V26   V27   V28  Amount  Class
# 0 -0.11  0.07  0.13 -0.19  0.13 -0.02  149.62      0
# 1  0.10 -0.34  0.17  0.13 -0.01  0.01    2.69      0
# 2  0.91 -0.69 -0.33 -0.14 -0.06 -0.06  378.66      0
# 3 -0.19 -1.18  0.65 -0.22  0.06  0.06  123.50      0
# 4 -0.14  0.14 -0.21  0.50  0.22  0.22   69.99      0
#
# [5 rows x 31 columns]

# %%
df = df.sample(frac = 0.01)

# %%
y = df["Class"]
X = df.drop(["Class"],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

# LazyRegressor.LazyRegressor
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████| 43/43 [00:05<00:00,  7.45it/s]

# %%
print(models)
# Out:
#                                 Accuracy  Balanced Accuracy  ROC AUC  \
# Model
# AdaBoostClassifier                  1.00               0.50     0.50
# LabelPropagation                    1.00               0.50     0.50
# XGBClassifier                       1.00               0.50     0.50
# RidgeClassifierCV                   1.00               0.50     0.50
# RidgeClassifier                     1.00               0.50     0.50
# RandomForestClassifier              1.00               0.50     0.50
# MLPClassifier                       1.00               0.50     0.50
# LinearDiscriminantAnalysis          1.00               0.50     0.50
# LabelSpreading                      1.00               0.50     0.50
# KNeighborsClassifier                1.00               0.50     0.50
# BaggingClassifier                   1.00               0.50     0.50
# HistGradientBoostingClassifier      1.00               0.50     0.50
# GaussianNB                          1.00               0.50     0.50
# ExtraTreesClassifier                1.00               0.50     0.50
# ExtraTreeClassifier                 1.00               0.50     0.50
# DummyClassifier                     1.00               0.50     0.50
# DecisionTreeClassifier              1.00               0.50     0.50
# BernoulliNB                         1.00               0.50     0.50
# LGBMClassifier                      1.00               0.50     0.50
#
#                                 F1 Score  Time Taken
# Model
# AdaBoostClassifier                  1.00        1.08
# LabelPropagation                    1.00        0.64
# XGBClassifier                       1.00        0.33
# RidgeClassifierCV                   1.00        0.05
# RidgeClassifier                     1.00        0.06
# RandomForestClassifier              1.00        0.16
# MLPClassifier                       1.00        0.83
# LinearDiscriminantAnalysis          1.00        1.02
# LabelSpreading                      1.00        0.39
# KNeighborsClassifier                1.00        0.08
# BaggingClassifier                   1.00        0.05
# HistGradientBoostingClassifier      1.00        0.10
# GaussianNB                          1.00        0.01
# ExtraTreesClassifier                1.00        0.09
# ExtraTreeClassifier                 1.00        0.01
# DummyClassifier                     1.00        0.01
# DecisionTreeClassifier              1.00        0.01
# BernoulliNB                         1.00        0.16
# LGBMClassifier                      1.00        0.36
