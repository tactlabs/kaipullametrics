# %%
import pandas as pd
import numpy as nm
from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/home/dhanya/Desktop/tact/Datasets/heart_Attack_possibility/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0     2.30      0
# 1   37    1   2       130   250    0        1      187      0     3.50      0
# 2   41    0   1       130   204    0        0      172      0     1.40      2
# 3   56    1   1       120   236    0        1      178      0     0.80      2
# 4   57    0   0       120   354    0        1      163      1     0.60      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.drop(["target"],axis=1)
y = df.target

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████| 43/43 [00:01<00:00, 22.95it/s]

# %%
print(models.Accuracy)
print(nm.mean(models.Accuracy))
# Out:
# Model
# GaussianNB                       0.84
# QuadraticDiscriminantAnalysis    0.82
# LabelSpreading                   0.79
# BernoulliNB                      0.79
# NearestCentroid                  0.79
# KNeighborsClassifier             0.79
# LabelPropagation                 0.79
# SGDClassifier                    0.79
# RandomForestClassifier           0.77
# GaussianProcessClassifier        0.77
# NuSVC                            0.77
# BaggingClassifier                0.77
# LogisticRegression               0.75
# LinearDiscriminantAnalysis       0.75
# LinearSVC                        0.75
# RidgeClassifierCV                0.75
# ExtraTreesClassifier             0.75
# CalibratedClassifierCV           0.75
# RidgeClassifier                  0.75
# SVC                              0.75
# PassiveAggressiveClassifier      0.74
# ExtraTreeClassifier              0.74
# AdaBoostClassifier               0.74
# LogisticRegressionCV             0.74
# DecisionTreeClassifier           0.74
# MLPClassifier                    0.72
# LGBMClassifier                   0.72
# HistGradientBoostingClassifier   0.70
# GradientBoostingClassifier       0.70
# XGBClassifier                    0.70
# Perceptron                       0.57
# DummyClassifier                  0.51
# Name: Accuracy, dtype: float64
# 0.7443647540983607
