# %%
import prettymetrics

from prettymetrics.supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("../examples/dataset/vegetable.csv")

# %%
data.head()
# Out:
#   Vegetable  Season Month  Temp Deasaster Happen in last 3month  \
# 0    potato  winter   jan    15                              no
# 1   tomato   winter   jan    15                              no
# 2      peas  winter   jan    15                              no
# 3    pumkin  winter   jan    15                              no
# 4  cucumber  winter   jan    15                              no
#
#   Vegetable condition  Price per kg
# 0               fresh            20
# 1               fresh            50
# 2               fresh            70
# 3               fresh            25
# 4               fresh            20

# %%
data.isnull().sum()
# Out:
# Vegetable                          0
# Season                             0
# Month                              0
# Temp                               0
# Deasaster Happen in last 3month    0
# Vegetable condition                0
# Price per kg                       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Vegetable', 'Season', 'Month', 'Temp',
#        'Deasaster Happen in last 3month', 'Vegetable condition',
#        'Price per kg'],
#       dtype='object')

# %%
X = data.drop(["Price per kg"], axis = 1)
y = data["Price per kg"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 56/56 [00:03<00:00, 18.28it/s]
#                                                   Adjusted R-Squared  \
# Model
# GradientBoostingRegressor                                       0.71
# XGBRegressor                                                    0.71
# RandomForestRegressor                                           0.70
# ExtraTreeRegressor                                              0.67
# BaggingRegressor                                                0.66
# AdaBoostRegressor                                               0.65
# DecisionTreeRegressor                                           0.65
# ExtraTreesRegressor                                             0.42
# HistGradientBoostingRegressor                                   0.32
# LGBMRegressor                                                   0.32
# PoissonRegressor                                                0.03
# RidgeCV                                                         0.03
# LassoLarsCV                                                     0.02
# TransformedTargetRegressor                                      0.02
# LinearRegression                                                0.02
# LarsCV                                                          0.00
# LassoLarsIC                                                    -0.00
# LassoCV                                                        -0.00
# Ridge                                                          -0.01
# PLSRegression                                                  -0.01
# CCA                                                            -0.01
# Lasso                                                          -0.02
# Lars                                                           -0.03
# ElasticNetCV                                                   -0.03
# KernelRidge                                                    -0.06
# ARDRegression                                                  -0.08
# HuberRegressor                                                 -0.08
# SGDRegressor                                                   -0.09
# OrthogonalMatchingPursuitCV                                    -0.10
# OrthogonalMatchingPursuit                                      -0.11
# TheilSenRegressor                                              -0.16
# ElasticNet                                                     -0.17
# LassoLars                                                      -0.17
# KNeighborsRegressor                                            -0.17
# TweedieRegressor                                               -0.22
# GammaRegressor                                                 -0.26
# GaussianProcessRegressor                                       -0.31
# BayesianRidge                                                  -0.36
# DummyRegressor                                                 -0.36
# NuSVR                                                          -0.44
# MLPRegressor                                                   -0.64
# LinearSVR                                                      -0.70
# PLSCanonical                                                   -0.71
# SVR                                                            -0.73
# RANSACRegressor                                                -0.88
# PassiveAggressiveRegressor                                     -0.97
# RadiusNeighborsRegressor      -8114712808721764118240958762450944.00
#
#                                                            R-Squared  \
# Model
# GradientBoostingRegressor                                       0.79
# XGBRegressor                                                    0.78
# RandomForestRegressor                                           0.77
# ExtraTreeRegressor                                              0.75
# BaggingRegressor                                                0.74
# AdaBoostRegressor                                               0.74
# DecisionTreeRegressor                                           0.73
# ExtraTreesRegressor                                             0.56
# HistGradientBoostingRegressor                                   0.49
# LGBMRegressor                                                   0.49
# PoissonRegressor                                                0.27
# RidgeCV                                                         0.27
# LassoLarsCV                                                     0.26
# TransformedTargetRegressor                                      0.26
# LinearRegression                                                0.26
# LarsCV                                                          0.25
# LassoLarsIC                                                     0.25
# LassoCV                                                         0.25
# Ridge                                                           0.25
# PLSRegression                                                   0.24
# CCA                                                             0.24
# Lasso                                                           0.24
# Lars                                                            0.23
# ElasticNetCV                                                    0.23
# KernelRidge                                                     0.21
# ARDRegression                                                   0.19
# HuberRegressor                                                  0.19
# SGDRegressor                                                    0.18
# OrthogonalMatchingPursuitCV                                     0.17
# OrthogonalMatchingPursuit                                       0.17
# TheilSenRegressor                                               0.13
# ElasticNet                                                      0.13
# LassoLars                                                       0.12
# KNeighborsRegressor                                             0.12
# TweedieRegressor                                                0.09
# GammaRegressor                                                  0.06
# GaussianProcessRegressor                                        0.02
# BayesianRidge                                                  -0.02
# DummyRegressor                                                 -0.02
# NuSVR                                                          -0.08
# MLPRegressor                                                   -0.23
# LinearSVR                                                      -0.27
# PLSCanonical                                                   -0.28
# SVR                                                            -0.30
# RANSACRegressor                                                -0.41
# PassiveAggressiveRegressor                                     -0.48
# RadiusNeighborsRegressor      -6086034606541323376911095223549952.00
#
#                                                 RMSE  Time Taken
# Model
# GradientBoostingRegressor                      21.88        0.05
# XGBRegressor                                   22.03        0.03
# RandomForestRegressor                          22.53        0.12
# ExtraTreeRegressor                             23.50        0.02
# BaggingRegressor                               23.89        0.05
# AdaBoostRegressor                              24.20        0.09
# DecisionTreeRegressor                          24.35        0.03
# ExtraTreesRegressor                            31.28        0.08
# HistGradientBoostingRegressor                  33.69        0.22
# LGBMRegressor                                  33.84        0.03
# PoissonRegressor                               40.38        0.03
# RidgeCV                                        40.44        0.02
# LassoLarsCV                                    40.63        0.03
# TransformedTargetRegressor                     40.64        0.03
# LinearRegression                               40.64        0.02
# LarsCV                                         40.95        0.05
# LassoLarsIC                                    40.96        0.02
# LassoCV                                        40.97        0.11
# Ridge                                          41.06        0.02
# PLSRegression                                  41.24        0.02
# CCA                                            41.25        0.03
# Lasso                                          41.26        0.03
# Lars                                           41.47        0.03
# ElasticNetCV                                   41.53        0.06
# KernelRidge                                    42.16        0.02
# ARDRegression                                  42.50        0.06
# HuberRegressor                                 42.61        0.04
# SGDRegressor                                   42.83        0.02
# OrthogonalMatchingPursuitCV                    42.96        0.05
# OrthogonalMatchingPursuit                      43.11        0.03
# TheilSenRegressor                              44.11        0.98
# ElasticNet                                     44.21        0.02
# LassoLars                                      44.35        0.02
# KNeighborsRegressor                            44.36        0.02
# TweedieRegressor                               45.15        0.02
# GammaRegressor                                 45.89        0.02
# GaussianProcessRegressor                       46.85        0.02
# BayesianRidge                                  47.71        0.03
# DummyRegressor                                 47.72        0.02
# NuSVR                                          49.08        0.03
# MLPRegressor                                   52.45        0.16
# LinearSVR                                      53.37        0.02
# PLSCanonical                                   53.51        0.03
# SVR                                            53.86        0.02
# RANSACRegressor                                56.21        0.06
# PassiveAggressiveRegressor                     57.44        0.02
# RadiusNeighborsRegressor      3689348814741910528.00        0.02
