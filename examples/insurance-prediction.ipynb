# %% [markdown]
# ### Insurance Pay Prediction (Regression)

# %%
import pandas as pd
from prettymetrics.supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  charges
# 0      19  female 27.90         0    yes  southwest 16884.92
# 1      18    male 33.77         1     no  southeast  1725.55
# 2      28    male 33.00         3     no  southeast  4449.46
# 3      33    male 22.70         0     no  northwest 21984.47
# 4      32    male 28.88         0     no  northwest  3866.86
# ...   ...     ...   ...       ...    ...        ...      ...
# 1333   50    male 30.97         3     no  northwest 10600.55
# 1334   18  female 31.92         0     no  northeast  2205.98
# 1335   18  female 36.85         0     no  southeast  1629.83
# 1336   21  female 25.80         0     no  southwest  2007.94
# 1337   61  female 29.07         0    yes  northwest 29141.36
#
# [1338 rows x 7 columns]

# %%
df['smoker']=pd.get_dummies(df['smoker'])['yes']
df['sex']=pd.get_dummies(df['sex'])['male']

# %%
df.drop('region',axis=1,inplace=True)

# %%
df
# Out:
#       age  sex   bmi  children  smoker  charges
# 0      19    0 27.90         0       1 16884.92
# 1      18    1 33.77         1       0  1725.55
# 2      28    1 33.00         3       0  4449.46
# 3      33    1 22.70         0       0 21984.47
# 4      32    1 28.88         0       0  3866.86
# ...   ...  ...   ...       ...     ...      ...
# 1333   50    1 30.97         3       0 10600.55
# 1334   18    0 31.92         0       0  2205.98
# 1335   18    0 36.85         0       0  1629.83
# 1336   21    0 25.80         0       0  2007.94
# 1337   61    0 29.07         0       1 29141.36
#
# [1338 rows x 6 columns]

# %%
X, y = shuffle(df[df.columns[:-1]], df['charges'], random_state=13)
X = X.astype(np.float32)

# %%
offset = int(X.shape[0] * 0.9)

# %%
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#  34%|█████████████████████████▊                                                  | 19/56 [00:01<00:02, 17.73it/s]
# IsotonicRegression model failed to execute
# Isotonic regression input X should be a 1d array or 2d array with 1 feature
#  62%|███████████████████████████████████████████████▌                            | 35/56 [00:03<00:02,  9.50it/s]
# MultiOutputRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimator'
# MultiTaskElasticNet model failed to execute
# For mono-task outputs, use ElasticNet
# MultiTaskElasticNetCV model failed to execute
# For mono-task outputs, use ElasticNetCVCV
# MultiTaskLasso model failed to execute
# For mono-task outputs, use ElasticNet
# MultiTaskLassoCV model failed to execute
# For mono-task outputs, use LassoCVCV
#  77%|██████████████████████████████████████████████████████████▎                 | 43/56 [00:03<00:00, 14.95it/s]
# RadiusNeighborsRegressor model failed to execute
# Input contains NaN, infinity or a value too large for dtype('float64').
#  86%|█████████████████████████████████████████████████████████████████▏          | 48/56 [00:03<00:00, 16.31it/s]
# RegressorChain model failed to execute
# __init__() missing 1 required positional argument: 'base_estimator'
# StackingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|████████████████████████████████████████████████████████████████████████████| 56/56 [00:04<00:00, 13.53it/s]
# VotingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# GradientBoostingRegressor                    0.86       0.87   4587.41
# RandomForestRegressor                        0.86       0.86   4725.40
# HistGradientBoostingRegressor                0.85       0.86   4762.44
# LGBMRegressor                                0.85       0.86   4793.79
# AdaBoostRegressor                            0.85       0.85   4897.75
# BaggingRegressor                             0.84       0.84   5006.52
# XGBRegressor                                 0.83       0.84   5072.06
# ExtraTreesRegressor                          0.82       0.82   5327.05
# KNeighborsRegressor                          0.81       0.82   5399.17
# DecisionTreeRegressor                        0.76       0.77   6064.73
# ARDRegression                                0.76       0.77   6148.23
# LassoLarsIC                                  0.76       0.76   6153.10
# LassoLars                                    0.75       0.76   6170.53
# LassoCV                                      0.75       0.76   6175.28
# PLSRegression                                0.75       0.76   6175.37
# BayesianRidge                                0.75       0.76   6176.30
# Ridge                                        0.75       0.76   6176.65
# RidgeCV                                      0.75       0.76   6176.65
# Lasso                                        0.75       0.76   6176.97
# LinearRegression                             0.75       0.76   6177.18
# TransformedTargetRegressor                   0.75       0.76   6177.18
# LassoLarsCV                                  0.75       0.76   6177.18
# LarsCV                                       0.75       0.76   6177.18
# Lars                                         0.75       0.76   6177.18
# OrthogonalMatchingPursuitCV                  0.75       0.76   6177.18
# SGDRegressor                                 0.75       0.76   6180.13
# PLSCanonical                                 0.75       0.76   6271.80
# ExtraTreeRegressor                           0.74       0.75   6287.97
# CCA                                          0.73       0.74   6476.65
# PoissonRegressor                             0.72       0.73   6638.77
# ElasticNet                                   0.67       0.69   7106.05
# HuberRegressor                               0.64       0.66   7439.52
# PassiveAggressiveRegressor                   0.64       0.66   7439.77
# OrthogonalMatchingPursuit                    0.64       0.65   7481.88
# RANSACRegressor                              0.58       0.60   8054.25
# TheilSenRegressor                            0.57       0.59   8146.57
# TweedieRegressor                             0.56       0.58   8224.56
# GammaRegressor                               0.52       0.53   8657.96
# ElasticNetCV                                 0.10       0.14  11791.96
# DummyRegressor                              -0.05      -0.01  12732.25
# NuSVR                                       -0.13      -0.08  13208.24
# SVR                                         -0.19      -0.14  13571.88
# KernelRidge                                 -0.33      -0.28  14350.18
# LinearSVR                                   -1.14      -1.06  18203.15
# MLPRegressor                                -1.23      -1.15  18580.23
# GaussianProcessRegressor                 -1874.95   -1804.43 538988.74
#
#                                Time Taken
# Model
# GradientBoostingRegressor            0.12
# RandomForestRegressor                0.21
# HistGradientBoostingRegressor        0.27
# LGBMRegressor                        0.06
# AdaBoostRegressor                    0.02
# BaggingRegressor                     0.04
# XGBRegressor                         0.04
# ExtraTreesRegressor                  0.16
# KNeighborsRegressor                  0.01
# DecisionTreeRegressor                0.01
# ARDRegression                        0.04
# LassoLarsIC                          0.01
# LassoLars                            0.01
# LassoCV                              0.06
# PLSRegression                        0.01
# BayesianRidge                        0.01
# Ridge                                0.01
# RidgeCV                              0.01
# Lasso                                0.01
# LinearRegression                     0.01
# TransformedTargetRegressor           0.01
# LassoLarsCV                          0.02
# LarsCV                               0.05
# Lars                                 0.02
# OrthogonalMatchingPursuitCV          0.01
# SGDRegressor                         0.01
# PLSCanonical                         0.01
# ExtraTreeRegressor                   0.01
# CCA                                  0.01
# PoissonRegressor                     0.01
# ElasticNet                           0.01
# HuberRegressor                       0.02
# PassiveAggressiveRegressor           0.02
# OrthogonalMatchingPursuit            0.01
# RANSACRegressor                      0.02
# TheilSenRegressor                    0.51
# TweedieRegressor                     0.01
# GammaRegressor                       0.01
# ElasticNetCV                         0.04
# DummyRegressor                       0.01
# NuSVR                                0.10
# SVR                                  0.06
# KernelRidge                          0.08
# LinearSVR                            0.01
# MLPRegressor                         1.77
# GaussianProcessRegressor             0.16
