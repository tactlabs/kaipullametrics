# %% [markdown]
# ### Classification of glass.csv

# %%
import pandas as pd
import numpy as np

# %%
from prettymetrics.supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('examples/datasets/glass.csv')

# %%
df
# Out:
#       RI    Na   Mg   Al    Si    K   Ca   Ba   Fe  Type
# 0   1.52 13.64 4.49 1.10 71.78 0.06 8.75 0.00 0.00     1
# 1   1.52 13.89 3.60 1.36 72.73 0.48 7.83 0.00 0.00     1
# 2   1.52 13.53 3.55 1.54 72.99 0.39 7.78 0.00 0.00     1
# 3   1.52 13.21 3.69 1.29 72.61 0.57 8.22 0.00 0.00     1
# 4   1.52 13.27 3.62 1.24 73.08 0.55 8.07 0.00 0.00     1
# ..   ...   ...  ...  ...   ...  ...  ...  ...  ...   ...
# 209 1.52 14.14 0.00 2.88 72.61 0.08 9.18 1.06 0.00     7
# 210 1.52 14.92 0.00 1.99 73.06 0.00 8.40 1.59 0.00     7
# 211 1.52 14.36 0.00 2.02 73.42 0.00 8.44 1.64 0.00     7
# 212 1.52 14.38 0.00 1.94 73.61 0.00 8.48 1.57 0.00     7
# 213 1.52 14.23 0.00 2.08 73.36 0.00 8.62 1.67 0.00     7
#
# [214 rows x 10 columns]

# %%
X=df[df.columns[:-1]]
y=df['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 43/43 [00:06<00:00,  6.28it/s]

# %%
print(models)
# Out:
#                                 Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# GaussianProcessClassifier           0.72               0.59    None      0.69
# XGBClassifier                       0.73               0.58    None      0.70
# ExtraTreesClassifier                0.76               0.58    None      0.72
# LabelPropagation                    0.68               0.58    None      0.68
# LabelSpreading                      0.68               0.58    None      0.68
# MLPClassifier                       0.69               0.54    None      0.66
# BaggingClassifier                   0.67               0.53    None      0.63
# SGDClassifier                       0.54               0.53    None      0.52
# RandomForestClassifier              0.73               0.53    None      0.68
# DecisionTreeClassifier              0.67               0.52    None      0.65
# BernoulliNB                         0.64               0.52    None      0.61
# LinearDiscriminantAnalysis          0.64               0.51    None      0.61
# LinearSVC                           0.63               0.51    None      0.58
# GradientBoostingClassifier          0.69               0.50    None      0.66
# LogisticRegressionCV                0.62               0.50    None      0.58
# ExtraTreeClassifier                 0.55               0.50    None      0.54
# LGBMClassifier                      0.67               0.49    None      0.63
# HistGradientBoostingClassifier      0.67               0.49    None      0.63
# LogisticRegression                  0.59               0.49    None      0.55
# NearestCentroid                     0.50               0.48    None      0.49
# SVC                                 0.63               0.46    None      0.59
# PassiveAggressiveClassifier         0.51               0.46    None      0.43
# GaussianNB                          0.29               0.42    None      0.29
# KNeighborsClassifier                0.63               0.42    None      0.58
# RidgeClassifier                     0.58               0.40    None      0.52
# RidgeClassifierCV                   0.58               0.40    None      0.52
# CalibratedClassifierCV              0.60               0.39    None      0.53
# Perceptron                          0.49               0.39    None      0.39
# AdaBoostClassifier                  0.38               0.35    None      0.24
# QuadraticDiscriminantAnalysis       0.45               0.30    None      0.41
# DummyClassifier                     0.32               0.17    None      0.15
#
#                                 Time Taken
# Model
# GaussianProcessClassifier             0.48
# XGBClassifier                         0.21
# ExtraTreesClassifier                  0.17
# LabelPropagation                      0.02
# LabelSpreading                        0.02
# MLPClassifier                         0.22
# BaggingClassifier                     0.05
# SGDClassifier                         0.02
# RandomForestClassifier                0.28
# DecisionTreeClassifier                0.02
# BernoulliNB                           0.02
# LinearDiscriminantAnalysis            0.02
# LinearSVC                             0.03
# GradientBoostingClassifier            0.85
# LogisticRegressionCV                  1.14
# ExtraTreeClassifier                   0.02
# LGBMClassifier                        0.28
# HistGradientBoostingClassifier        2.36
# LogisticRegression                    0.05
# NearestCentroid                       0.01
# SVC                                   0.02
# PassiveAggressiveClassifier           0.02
# GaussianNB                            0.03
# KNeighborsClassifier                  0.02
# RidgeClassifier                       0.03
# RidgeClassifierCV                     0.02
# CalibratedClassifierCV                0.12
# Perceptron                            0.02
# AdaBoostClassifier                    0.18
# QuadraticDiscriminantAnalysis         0.02
# DummyClassifier                       0.02
